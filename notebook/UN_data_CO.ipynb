# %% [markdown]
# Notebook #5

# %% [markdown]
# # Colonialism (issue codes = CO)

# %% [markdown]
# **Link:** https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/T9SDEW
#
# **Data Title:** Colonial Dates Dataset (COLDAT)
#
# **Author:** Becker, Bastian
#
# **Year:** 2019
#
# **Published:** Harvard Dataverse

# %% [markdown]
# ## Load Data

# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import collections
import math

# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
UN_data_df = pd.read_csv('/content/drive/MyDrive/Senior_Year/Fall_2021/Research/data/output_data/UN_data_with_GDP_Developed_HR_NU_DI.csv', sep=',')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# colonialism data 
colonialism_df = pd.read_csv('/content/drive/MyDrive/Senior_Year/Fall_2021/Research/data/input_data/COLDAT_colonies.csv', sep=',', encoding='latin-1')

# %% [markdown]
# ## Understanding Data

# %%
colonialism_df.head()
# Out:
#        country  col.belgium  ...  colend.portugal_mean  colend.spain_mean
# 0  Afghanistan            0  ...                   NaN                NaN
# 1      Albania            0  ...                   NaN                NaN
# 2      Algeria            0  ...                   NaN                NaN
# 3      Andorra            0  ...                   NaN                NaN
# 4       Angola            0  ...                1974.0                NaN
#
# [5 rows x 41 columns]

# %%
len(colonialism_df)
# Out:
# 195

# %%
colonialism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   country                    195 non-null    object
#  1   col.belgium                195 non-null    int64
#  2   col.britain                195 non-null    int64
#  3   col.france                 195 non-null    int64
#  4   col.germany                195 non-null    int64
#  5   col.italy                  195 non-null    int64
#  6   col.netherlands            195 non-null    int64
#  7   col.portugal               195 non-null    int64
#  8   col.spain                  195 non-null    int64
#  9   colstart.belgium_max       3 non-null      float64
#  10  colstart.britain_max       70 non-null     float64
#  11  colstart.france_max        34 non-null     float64
#  12  colstart.germany_max       12 non-null     float64
#  13  colstart.italy_max         3 non-null      float64
#  14  colstart.netherlands_max   4 non-null      float64
#  15  colstart.portugal_max      12 non-null     float64
#  16  colstart.spain_max         27 non-null     float64
#  17  colend.belgium_max         3 non-null      float64
#  18  colend.britain_max         70 non-null     float64
#  19  colend.france_max          34 non-null     float64
#  20  colend.germany_max         12 non-null     float64
#  21  colend.italy_max           3 non-null      float64
#  22  colend.netherlands_max     4 non-null      float64
#  23  colend.portugal_max        12 non-null     float64
#  24  colend.spain_max           27 non-null     float64
#  25  colstart.belgium_mean      3 non-null      float64
#  26  colstart.britain_mean      70 non-null     float64
#  27  colstart.france_mean       34 non-null     float64
#  28  colstart.germany_mean      12 non-null     float64
#  29  colstart.italy_mean        3 non-null      float64
#  30  colstart.netherlands_mean  4 non-null      float64
#  31  colstart.portugal_mean     12 non-null     float64
#  32  colstart.spain_mean        27 non-null     float64
#  33  colend.belgium_mean        3 non-null      float64
#  34  colend.britain_mean        70 non-null     float64
#  35  colend.france_mean         34 non-null     float64
#  36  colend.germany_mean        12 non-null     float64
#  37  colend.italy_mean          3 non-null      float64
#  38  colend.netherlands_mean    4 non-null      float64
#  39  colend.portugal_mean       12 non-null     float64
#  40  colend.spain_mean          27 non-null     float64
# dtypes: float64(32), int64(8), object(1)
# memory usage: 62.6+ KB

# %%
colonialism_df.describe()
# Out:
#               Year  Nuclear weapons inventory by country (FAS Nuclear Notebook)
# count   657.000000                                         657.000000
# mean   1981.000000                                        3118.324201
# std      21.087362                                        7778.915516
# min    1945.000000                                           0.000000
# 25%    1963.000000                                           0.000000
# 50%    1981.000000                                          63.000000
# 75%    1999.000000                                         350.000000
# max    2017.000000                                       40159.000000

# %%
colonialism_df.isnull().sum()
# Out:
# Entity                                                         0
# Code                                                           0
# Year                                                           0
# Nuclear weapons inventory by country (FAS Nuclear Notebook)    0
# dtype: int64

# %%
colonialism_df.columns
# Out:
# Index(['country', 'col.belgium', 'col.britain', 'col.france', 'col.germany',
#        'col.italy', 'col.netherlands', 'col.portugal', 'col.spain',
#        'colstart.belgium_max', 'colstart.britain_max', 'colstart.france_max',
#        'colstart.germany_max', 'colstart.italy_max',
#        'colstart.netherlands_max', 'colstart.portugal_max',
#        'colstart.spain_max', 'colend.belgium_max', 'colend.britain_max',
#        'colend.france_max', 'colend.germany_max', 'colend.italy_max',
#        'colend.netherlands_max', 'colend.portugal_max', 'colend.spain_max',
#        'colstart.belgium_mean', 'colstart.britain_mean',
#        'colstart.france_mean', 'colstart.germany_mean', 'colstart.italy_mean',
#        'colstart.netherlands_mean', 'colstart.portugal_mean',
#        'colstart.spain_mean', 'colend.belgium_mean', 'colend.britain_mean',
#        'colend.france_mean', 'colend.germany_mean', 'colend.italy_mean',
#        'colend.netherlands_mean', 'colend.portugal_mean', 'colend.spain_mean'],
#       dtype='object')

# %% [markdown]
# ## Create New Column

# %%
# add country code to main dataset
codes = UN_data_df[['country', 'countryname']]

# %%
codes.drop_duplicates(inplace=True)
codes.reset_index(drop=True, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
len(codes)
# Out:
# 204

# %%
# drop unimportant columns
colonialism_df = colonialism_df.drop(['colstart.belgium_max', 'colstart.britain_max', 'colstart.france_max',
       'colstart.germany_max', 'colstart.italy_max',
       'colstart.netherlands_max', 'colstart.portugal_max',
       'colstart.spain_max', 'colend.belgium_max', 'colend.britain_max',
       'colend.france_max', 'colend.germany_max', 'colend.italy_max',
       'colend.netherlands_max', 'colend.portugal_max', 'colend.spain_max',
       'colstart.belgium_mean', 'colstart.britain_mean',
       'colstart.france_mean', 'colstart.germany_mean', 'colstart.italy_mean',
       'colstart.netherlands_mean', 'colstart.portugal_mean',
       'colstart.spain_mean', 'colend.belgium_mean', 'colend.britain_mean',
       'colend.france_mean', 'colend.germany_mean', 'colend.italy_mean',
       'colend.netherlands_mean', 'colend.portugal_mean', 'colend.spain_mean'], axis=1)

# %%
# rename columns
colonialism_df = colonialism_df.rename(columns={'country':'countryname'})

# %%
colonialism_df.head()
# Out:
#    countryname  col.belgium  ...  col.portugal  col.spain
# 0  Afghanistan            0  ...             0          0
# 1      Albania            0  ...             0          0
# 2      Algeria            0  ...             0          0
# 3      Andorra            0  ...             0          0
# 4       Angola            0  ...             1          0
#
# [5 rows x 9 columns]

# %%
# merge on countryname 
colonialism_df = pd.merge(colonialism_df, codes, on=['countryname'], how='left')

# %%
# create new dataset and column
colonialism_df['colony?'] = colonialism_df['col.belgium'] +	colonialism_df['col.britain']	+	colonialism_df['col.france'] + colonialism_df['col.germany'] +	colonialism_df['col.italy']	+	colonialism_df['col.netherlands']	+	colonialism_df['col.portugal']	+	colonialism_df['col.spain']

# %%
colonialism_df.columns
# Out:
# Index(['countryname', 'col.belgium', 'col.britain', 'col.france',
#        'col.germany', 'col.italy', 'col.netherlands', 'col.portugal',
#        'col.spain', 'country', 'colony?'],
#       dtype='object')

# %%
colonialism_df = colonialism_df.drop(['countryname', 'col.belgium', 'col.britain', 'col.france', 'col.germany',
       'col.italy', 'col.netherlands', 'col.portugal', 'col.spain'], axis = 1)

# %%
#  if a row in "colony?"=0, then do nothing. If a row in "colony?">0, then make "colony?"=1. 
colonialism_df.loc[colonialism_df['colony?'] > 0, 'colony?'] = 1

# %%
colonialism_df['colony?'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ## Merge

# %%
# merge with original and save 
temp = pd.merge(UN_data_df, colonialism_df, on=['country'], how='left')

# %% [markdown]
# ## Save

# %%
temp.to_csv(r'/content/drive/MyDrive/Senior_Year/Fall_2021/Research/data/output_data/UN_data_with_GDP_Developed_HR_NU_DI_CO.csv', index = False)
